# %% [markdown]
# Perfeito.
# O próximo tópico da sequência é:
#
# ---
#
# ## 🧱 Tópico 6: `if`, `elif`, `else` (Estruturas Condicionais)
#
# ### 📌 Objetivo
#
# Entender como aplicar regras, filtros ou condições no seu código — como em SQL com `CASE WHEN` ou `WHERE`.
#
# ---
#
# ### ✅ Conceito
#
# A estrutura condicional permite executar diferentes blocos de código com base em uma condição lógica.
#
# ```python
# if condição:
#     # bloco 1
# elif outra_condição:
#     # bloco 2
# else:
#     # bloco 3
# ```
#
# ---
#
# ### ✅ Exemplo Prático
#
# ```python
# idade = 25
#
# if idade < 18:
#     print("Menor de idade")
# elif idade < 65:
#     print("Adulto")
# else:
#     print("Idoso")
# ```
#
# Saída:
# `Adulto`
#
# ---
#
# ### ✅ Com operadores lógicos
#
# ```python
# salario = 3200
#
# if salario > 3000 and salario <= 5000:
#     print("Classe média")
# ```
#
# ---
#
# ### 📌 Exercício
#
# Dada a lista de produtos abaixo, imprima a faixa de preço de cada um com base no valor:
#
# * Até 10 → **Barato**
# * Entre 10 e 100 → **Médio**
# * Acima de 100 → **Caro**
#
# ```python
# produtos = [
#     {'nome': 'Caneta', 'preco': 2.5},
#     {'nome': 'Headphone', 'preco': 150},
#     {'nome': 'Mouse', 'preco': 75},
#     {'nome': 'Monitor', 'preco': 200}
# ]
# ```
#
# 👉 Escreva o código que percorre a lista e imprime o nome do produto e sua classificação de preço.
#
# Me avise quando tiver pronto ou se quiser que eu valide sua resposta.

# %%
# Dada a lista de produtos abaixo, imprima a faixa de preço de cada um com base no valor:
# * Até 10 → **Barato**
# * Entre 10 e 100 → **Médio**
# * Acima de 100 → **Caro**

produtos = [
    {'nome': 'Caneta', 'preco': 2.5},
    {'nome': 'Headphone', 'preco': 150},
    {'nome': 'Mouse', 'preco': 75},
    {'nome': 'Monitor', 'preco': 200}
]

for produto in produtos:
    preco = produto['preco']
    nome = produto['nome']

    if preco > 100:
        faixa = 'Caro'
    elif preco >= 10:
        faixa = 'Médio'
    else:
        faixa = 'Barato'

    print(f"Produto: {nome}, Preço: {preco:.2f}€, Faixa: {faixa}")
# Out:
# Produto: Caneta, Preço: 2.50€, Faixa: Barato
# Produto: Headphone, Preço: 150.00€, Faixa: Caro
# Produto: Mouse, Preço: 75.00€, Faixa: Médio
# Produto: Monitor, Preço: 200.00€, Faixa: Caro

# %% [markdown]
# ## 🧠 Como pensar em **if dentro de for** — passo a passo para raciocínio lógico
#
# ---
#
# ### 1. Entenda o problema:
#
# Você tem uma **lista** de produtos e quer **avaliar cada produto individualmente** para classificar o preço.
#
# ---
#
# ### 2. Pense no que é repetido:
#
# Para cada produto da lista, você precisa:
#
# * Pegar o preço;
# * Aplicar regras (condições) para decidir a faixa (barato, médio, caro);
# * Imprimir o resultado.
#
# ---
#
# ### 3. O que é iterar com o `for`:
#
# Um loop `for` serve para **percorre cada item da lista** e executar algo para cada item.
#
# ```python
# for produto in produtos:
#     # aqui você está trabalhando com 1 produto por vez
# ```
#
# ---
#
# ### 4. Dentro do `for`, aplique as regras:
#
# Cada produto tem um preço, e para esse preço, você usa `if`, `elif`, `else` para definir a faixa.
#
# ```python
# if preco > 100:
#     faixa = 'Caro'
# elif preco >= 10:
#     faixa = 'Médio'
# else:
#     faixa = 'Barato'
# ```
#
# ---
#
# ### 5. Depois de decidir a faixa, faça a ação final, que no caso é imprimir.
#
# ---
#
# ### **Resumo do fluxo mental:**
#
# 1. Para cada produto na lista → **`for`**
# 2. Pega o preço → `preco = produto['preco']`
# 3. Decide faixa com condições → `if ... elif ... else`
# 4. Imprime resultado formatado → `print(f'...')`
#
# ---
#
# ### 💡 Dica para treinar:
#
# * Sempre pergunte: "Eu preciso repetir uma ação para vários itens?" → Use `for`.
# * Dentro da repetição, se quiser tomar decisões diferentes → Use `if`.
# * Separe a lógica em passos simples, por exemplo, calcule um valor, depois decida algo, depois imprima.
#
# ---

# %% [markdown]
# Perfeito, Pedro! Vamos com calma e foco, um exercício por vez.
#
# ---
#
# ## 🧪 Exercício 1: Classificação de Idade
#
# Dada a lista abaixo, escreva um código que percorre a lista e imprime a classificação de cada idade conforme:
#
# * Até 12 anos → `'Criança'`
# * Entre 13 e 19 → `'Adolescente'`
# * Entre 20 e 59 → `'Adulto'`
# * Acima de 59 → `'Idoso'`
#
# ```python
# idades = [5, 17, 25, 64, 12, 19, 45, 80]
# ```
#
# **Formato da saída esperada:**
#
# ```
# Idade 5: Criança
# Idade 17: Adolescente
# Idade 25: Adulto
# Idade 64: Idoso
# ...
# ```
#
# ---
#
# Faça o código, envie para eu corrigir e te ajudar se precisar.

# %%
idades = [5, 17, 25, 64, 12, 19, 45, 80]

for idade in idades:
    # Classificar a idade na faixa correta
    if idade <= 12:
        faixa = 'Criança'
    elif idade <= 19:
        faixa = 'Adolescente'
    elif idade <= 59:
        faixa = 'Adulto'
    else:
        faixa = 'Idoso'

    print(f"Idade {idade}: {faixa}")
# Out:
# Idade 5: Criança
# Idade 17: Adolescente
# Idade 25: Adulto
# Idade 64: Idoso
# Idade 12: Criança
# Idade 19: Adolescente
# Idade 45: Adulto
# Idade 80: Idoso

# %% [markdown]
# Ótimo, Pedro! Vamos para o próximo exercício.
#
# ---
#
# ## 🧪 Exercício 2: Verificação de Estoque
#
# Você tem uma lista de produtos com a quantidade em estoque. Para cada produto, imprima se está:
#
# * **Em estoque**: se a quantidade for maior que 0
# * **Esgotado**: se a quantidade for 0
#
# ```python
# produtos = [
#     {'nome': 'Teclado', 'estoque': 15},
#     {'nome': 'Mouse', 'estoque': 0},
#     {'nome': 'Monitor', 'estoque': 7},
#     {'nome': 'Gabinete', 'estoque': 0}
# ]
# ```
#
# **Formato esperado:**
#
# ```
# Produto: Teclado - Em estoque
# Produto: Mouse - Esgotado
# Produto: Monitor - Em estoque
# Produto: Gabinete - Esgotado
# ```
#
# ---
#
# Faça seu código, envie para eu revisar.

# %%
produtos = [
    {'nome': 'Teclado', 'estoque': 15},
    {'nome': 'Mouse', 'estoque': 0},
    {'nome': 'Monitor', 'estoque': 7},
    {'nome': 'Gabinete', 'estoque': 0}
]

for produto in produtos:
    nome = produto['nome']

    if produto['estoque'] > 0:
        stock_status = 'Em estoque'
    else:
        stock_status = 'Esgotado'
    
    print(f"Produto: {nome} - {stock_status}")
# Out:
# Produto: Teclado - Em estoque
# Produto: Mouse - Esgotado
# Produto: Monitor - Em estoque
# Produto: Gabinete - Esgotado

# %% [markdown]
# Ótimo! Vamos para o próximo exercício:
#
# ---
#
# ### 📊 **Exercício 4: Classificar alunos por nota final**
#
# Dada a lista de alunos com suas notas finais, imprima o nome e a classificação:
#
# * Nota **≥ 90** → **Excelente**
# * Nota **entre 70 e 89** → **Bom**
# * Nota **entre 50 e 69** → **Regular**
# * Nota **< 50** → **Insuficiente**
#
# ```python
# alunos = [
#     {'nome': 'Ana', 'nota': 95},
#     {'nome': 'Bruno', 'nota': 67},
#     {'nome': 'Carlos', 'nota': 82},
#     {'nome': 'Diana', 'nota': 45},
#     {'nome': 'Eduardo', 'nota': 73}
# ]
# ```
#
# 📥 **Tarefa**: Escreva um loop `for` que percorra a lista de alunos e imprima algo como:
#
# ```
# Aluno: Ana - Nota: 95 - Classificação: Excelente
# Aluno: Bruno - Nota: 67 - Classificação: Regular
# ...
# ```
#
# Quando terminar, envie sua resposta aqui.

# %%
alunos = [
    {'nome': 'Ana', 'nota': 95},
    {'nome': 'Bruno', 'nota': 67},
    {'nome': 'Carlos', 'nota': 82},
    {'nome': 'Diana', 'nota': 45},
    {'nome': 'Eduardo', 'nota': 73}
]

for aluno in alunos:
    nome = aluno['nome']
    nota = aluno['nota']

    if nota >= 90:
        classificacao = 'Excelente'
    elif nota >= 70:
        classificacao = 'Bom'
    elif nota >= 50:
        classificacao = 'Regular'
    else:
        classificacao = 'Insuficiente'

    print(f"Aluno: {nome} - Nota: {nota} - Classificação: {classificacao}")
# Out:
# Aluno: Ana - Nota: 95 - Classificação: Excelente
# Aluno: Bruno - Nota: 67 - Classificação: Regular
# Aluno: Carlos - Nota: 82 - Classificação: Bom
# Aluno: Diana - Nota: 45 - Classificação: Insuficiente
# Aluno: Eduardo - Nota: 73 - Classificação: Bom

# %% [markdown]
# ### 📦 **Exercício 5: Cálculo de preço com desconto**
#
# Você tem uma lista de produtos com seus respectivos preços e uma regra de desconto:
#
# * Se o preço for maior que 100, aplicar 10% de desconto
# * Caso contrário, aplicar 5% de desconto
#
# Imprima o nome do produto, o preço original e o preço com desconto.
#
# ```python
# produtos = [
#     {'nome': 'Cadeira Gamer', 'preco': 350},
#     {'nome': 'Mousepad', 'preco': 25},
#     {'nome': 'Webcam', 'preco': 89},
#     {'nome': 'Notebook', 'preco': 1200}
# ]
# ```
#
# 📥 **Saída esperada:**
#
# ```
# Produto: Cadeira Gamer - Preço original: 350 - Com desconto: 315.0
# Produto: Mousepad - Preço original: 25 - Com desconto: 23.75
# ...
# ```
#
# Quando estiver pronto, envie sua solução.

# %%
produtos = [
    {'nome': 'Cadeira Gamer', 'preco': 350},
    {'nome': 'Mousepad', 'preco': 25},
    {'nome': 'Webcam', 'preco': 89},
    {'nome': 'Notebook', 'preco': 1200}
]

for produto in produtos:
    nome = produto['nome']
    preco = produto['preco']

    if preco > 100:
        desconto = 0.1  # 10% de desconto
    else:
        desconto = 0.05

    preco_final = preco * (1 - desconto)

    print(f'Produto: {nome} - Preço original: {preco:.2f}€ - Desconto: {desconto*100:.0f}% - Preço com desconto: {preco_final:.2f}€')
# Out:
# Produto: Cadeira Gamer - Preço original: 350.00€ - Desconto: 10% - Preço com desconto: 315.00€
# Produto: Mousepad - Preço original: 25.00€ - Desconto: 5% - Preço com desconto: 23.75€
# Produto: Webcam - Preço original: 89.00€ - Desconto: 5% - Preço com desconto: 84.55€
# Produto: Notebook - Preço original: 1200.00€ - Desconto: 10% - Preço com desconto: 1080.00€

# %% [markdown]
# ### 🔁 Vamos seguir?
#
# Aqui está o **Exercício 6: Cálculo de média e classificação geral**.
#
# ---
#
# ### 📊 **Exercício 6: Média da turma e status individual**
#
# Dada a lista de alunos com suas respectivas notas, calcule a **média geral da turma** e, para cada aluno:
#
# * Informe se ele está **acima**, **na média**, ou **abaixo da média geral**
#
# ```python
# alunos = [
#     {'nome': 'Ana', 'nota': 8.5},
#     {'nome': 'Bruno', 'nota': 6.2},
#     {'nome': 'Carlos', 'nota': 7.8},
#     {'nome': 'Diana', 'nota': 9.1},
#     {'nome': 'Eduardo', 'nota': 5.4}
# ]
# ```
#
# 📥 **Saída esperada (exemplo):**
#
# ```
# Média da turma: 7.4
#
# Aluno: Ana - Nota: 8.5 - Acima da média
# Aluno: Bruno - Nota: 6.2 - Abaixo da média
# ...
# ```
#
# Quando estiver pronto, envie sua solução.

# %%
alunos = [
    {'nome': 'Ana', 'nota': 8.5},
    {'nome': 'Bruno', 'nota': 6.2},
    {'nome': 'Carlos', 'nota': 7.8},
    {'nome': 'Diana', 'nota': 9.1},
    {'nome': 'Eduardo', 'nota': 5.4}
]

soma = 0

for aluno in alunos:
    soma += aluno['nota']

media = soma / len(alunos)

print(f'Número de alunos: {len(alunos)}, Soma das notas: {soma:.2f}')
print(f'Média da turma: {media:.2f}')

print() # separador

for aluno in alunos:
    nome = aluno['nome']
    nota = aluno['nota']

    if nota >= media:
        situacao = 'Acima da média'
    else:
        situacao = 'Abaixo da média'

    print(f'Aluno: {nome} - Nota: {nota:.2f} - Situação: {situacao}')
# Out:
# Número de alunos: 5, Soma das notas: 37.00
# Média da turma: 7.40
#
# Aluno: Ana - Nota: 8.50 - Situação: Acima da média
# Aluno: Bruno - Nota: 6.20 - Situação: Abaixo da média
# Aluno: Carlos - Nota: 7.80 - Situação: Acima da média
# Aluno: Diana - Nota: 9.10 - Situação: Acima da média
# Aluno: Eduardo - Nota: 5.40 - Situação: Abaixo da média
